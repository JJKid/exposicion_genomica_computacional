# %% [markdown]
# # Proyecto final: RNA-Seq, PCA y K-Means
#
# Flujo reproducible para analizar el dataset Gene Expression Cancer RNA-Seq de UCI.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / "pyproject.toml").exists():
    ROOT = ROOT.parent
if not (ROOT / "src").exists():
    ROOT = Path.cwd().resolve().parent
sys.path.insert(0, str(ROOT / "src"))

from genomica_pca_kmeans.pipeline import run_pipeline

# %% [markdown]
# ## Ejecucion del pipeline
#
# Con conexion a internet, el pipeline descarga el dataset desde UCI. Sin conexion, coloca `data.csv` y `labels.csv` bajo `data/raw/` o pasa rutas locales al llamar `run_pipeline`.

# %%
result = run_pipeline(
    data_dir=ROOT / "data",
    figures_dir=ROOT / "figures",
    results_dir=ROOT / "results",
    n_top_genes=5000,
    n_components=10,
    k_min=2,
    k_max=10,
    random_state=42,
)
result.summary

# %% [markdown]
# ## Evaluacion interna de K-Means: Davies-Bouldin y Silhouette

# %%
result.kmeans.evaluation

# %% [markdown]
# ## Comparacion externa: matriz de contingencia, pureza, ARI y NMI

# %%
result.contingency
result.summary['cluster_label_metrics']

# %% [markdown]
# ## Figuras generadas

# %%
for name, path in result.figure_paths.items():
    print(f"{name}: {path}")
